# %% [raw]
# ---
# title: "Microsoft Officeアプリを起動すると、アカウントの問題、共有コンピューターでのOfficeライセンス認証に使用することはできません、と怒られる"
# description: "しらんがな感"
# author: "tesshy"
# date: "2023-08-08"
# categories:
#   - office
#   - windows
# ---

# %% [markdown]
# ![image.png](attachment:image.png)
#
# こんな表示が出る。もちらん共有なんぞしてない。そんな時は以下をdisable_OfficeSharedComputer.regとして保存して実行してどうぞ・・・（無保証、ただ自分の周りで使ってる限り失敗したことはない）
#
# 2023-10-09: 先頭行のレジストリバージョン宣言が抜けてたので追加・・・
#
# ```
# Windows Registry Editor Version 5.00
#
# [HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Office\ClickToRun\Configuration]
# "SharedComputerLicensing"="0"
# ```
#
# 正直原因がわからないが、なんかの拍子にSharedComputerLicensingが1になってしまうらしい。再現性がないのでよくわからん・・・。ワイがOfficeのライセンスについてなんか間違って認識してる可能性も否めない、が・・・。
